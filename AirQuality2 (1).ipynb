# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("E:/6th sem practicals/DSBDAL Practical/AirQuality.csv",encoding='cp1252')
# Out:
# C:\Users\Kajal\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0      150  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1      151  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2      152  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3      150     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4      151     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
# stn_code                       291665 non-null object
# sampling_date                  435739 non-null object
# state                          435742 non-null object
# location                       435739 non-null object
# agency                         286261 non-null object
# type                           430349 non-null object
# so2                            401096 non-null float64
# no2                            419509 non-null float64
# rspm                           395520 non-null float64
# spm                            198355 non-null float64
# location_monitoring_station    408251 non-null object
# pm2_5                          9314 non-null float64
# date                           435735 non-null object
# dtypes: float64(5), object(8)
# memory usage: 43.2+ MB

# %%
df.describe()
# Out:
#                  so2            no2           rspm            spm        pm2_5
# count  401096.000000  419509.000000  395520.000000  198355.000000  9314.000000
# mean       10.829414      25.809623     108.832784     220.783480    40.791467
# std        11.177187      18.503086      74.872430     151.395457    30.832525
# min         0.000000       0.000000       0.000000       0.000000     3.000000
# 25%         5.000000      14.000000      56.000000     111.000000    24.000000
# 50%         8.000000      22.000000      90.000000     187.000000    32.000000
# 75%        13.700000      32.200000     142.000000     296.000000    46.000000
# max       909.000000     876.000000    6307.033333    3380.000000   504.000000

# %%
df.isnull()
# Out:
#         stn_code  sampling_date  state  location  agency   type    so2    no2  \
# 0          False          False  False     False    True  False  False  False
# 1          False          False  False     False    True  False  False  False
# 2          False          False  False     False    True  False  False  False
# 3          False          False  False     False    True  False  False  False
# 4          False          False  False     False    True  False  False  False
# 5          False          False  False     False    True  False  False  False
# 6          False          False  False     False    True  False  False  False
# 7          False          False  False     False    True  False  False  False
# 8          False          False  False     False    True  False  False  False
# 9          False          False  False     False    True  False  False  False
# 10         False          False  False     False    True  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
df.shape
# Out:
# (435742, 13)

# %% [markdown]
# # data cleaning

# %%
df=df.drop(['stn_code', 'agency','location_monitoring_station'],axis=1)

# %%
df.isnull().sum()
# Out:
# sampling_date         3
# state                 0
# location              3
# type               5393
# so2               34646
# no2               16233
# rspm              40222
# spm              237387
# pm2_5            426428
# date                  7
# dtype: int64

# %%
df=df.dropna(subset=['date'])

# %%
df.isna().sum()
# Out:
# sampling_date         0
# state                 0
# location              0
# type               5390
# so2               34643
# no2               16230
# rspm              40219
# spm              237380
# pm2_5            426421
# date                  0
# dtype: int64

# %% [markdown]
# #changing the types of uniform format

# %%
df['type'].unique()
# Out:
# array(['Residential, Rural and other Areas', 'Industrial Area', nan,
#        'Sensitive Area', 'Industrial Areas', 'Residential and others',
#        'Sensitive Areas', 'Industrial', 'Residential', 'RIRUO',
#        'Sensitive'], dtype=object)

# %%
types={
    "Residential":"R",
    "Rural and other Areas":"ROA",
    "Industrial Area":"IA",
    "Sensitive Area":"SA",
    "Residential and others":"R",
    "Sensitive Areas":"SAS",
    "Industrial":"I",
    "Residential":"R",
    "RIRUO":"RIO",
    "Sensitive":"S"
    
}

# %%
df.type=df.type.replace(types)

# %%
df['type'].unique()
# Out:
# array(['Residential, Rural and other Areas', 'IA', nan, 'SA',
#        'Industrial Areas', 'R', 'SAS', 'I', 'RIO', 'S'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435735 entries, 0 to 435738
# Data columns (total 10 columns):
# sampling_date    435735 non-null object
# state            435735 non-null object
# location         435735 non-null object
# type             430345 non-null object
# so2              401092 non-null float64
# no2              419505 non-null float64
# rspm             395516 non-null float64
# spm              198355 non-null float64
# pm2_5            9314 non-null float64
# date             435735 non-null object
# dtypes: float64(5), object(5)
# memory usage: 36.6+ MB

# %% [markdown]
# # Data Transformation

# %%
df.duplicated().sum()
# Out:
# 1135

# %%
df.drop_duplicates()
# Out:
#               sampling_date           state   location  \
# 0        February - M021990  Andhra Pradesh  Hyderabad
# 1        February - M021990  Andhra Pradesh  Hyderabad
# 2        February - M021990  Andhra Pradesh  Hyderabad
# 3           March - M031990  Andhra Pradesh  Hyderabad
# 4           March - M031990  Andhra Pradesh  Hyderabad
# 5           March - M031990  Andhra Pradesh  Hyderabad
# 6           April - M041990  Andhra Pradesh  Hyderabad
# 7           April - M041990  Andhra Pradesh  Hyderabad
# 8           April - M041990  Andhra Pradesh  Hyderabad
# 9             May - M051990  Andhra Pradesh  Hyderabad
# 10            May - M051990  Andhra Pradesh  Hyderabad
# 11           June - M061990  Andhra Pradesh  Hyderabad
# 12           June - M061990  Andhra Pradesh  Hyderabad
# 13           June - M061990  Andhra Pradesh  Hyderabad
# 14           July - M071990  Andhra Pradesh  Hyderabad
# 15           July - M071990  Andhra Pradesh  Hyderabad
# ...

# %% [markdown]
# #simple replacement of categorical data with a number

# %%
df.head()
# Out:
#         sampling_date           state   location  \
# 0  February - M021990  Andhra Pradesh  Hyderabad
# 1  February - M021990  Andhra Pradesh  Hyderabad
# 2  February - M021990  Andhra Pradesh  Hyderabad
# 3     March - M031990  Andhra Pradesh  Hyderabad
# 4     March - M031990  Andhra Pradesh  Hyderabad
#
#                                  type  so2   no2  rspm  spm  pm2_5        date
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN    NaN  1990-02-01
# 1                                  IA  3.1   7.0   NaN  NaN    NaN  1990-02-01
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN    NaN  1990-02-01
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN    NaN  1990-03-01
# 4                                  IA  4.7   7.5   NaN  NaN    NaN  1990-03-01

# %%
df['type'].value_counts()
# Out:
# Residential, Rural and other Areas    179013
# IA                                     96089
# R                                      86949
# Industrial Areas                       51747
# SA                                      8979
# SAS                                     5536
# RIO                                     1304
# S                                        495
# I                                        233
# Name: type, dtype: int64

# %%
df['type'].replace({'IA': 1, 'R': 2, 'SA': 3, 'S': 4}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435735 entries, 0 to 435738
# Data columns (total 10 columns):
# sampling_date    435735 non-null object
# state            435735 non-null object
# location         435735 non-null object
# type             430345 non-null object
# so2              401092 non-null float64
# no2              419505 non-null float64
# rspm             395516 non-null float64
# spm              198355 non-null float64
# pm2_5            9314 non-null float64
# date             435735 non-null object
# dtypes: float64(5), object(5)
# memory usage: 36.6+ MB

# %%
df['type']
# Out:
# 0         Residential, Rural and other Areas
# 1                                          1
# 2         Residential, Rural and other Areas
# 3         Residential, Rural and other Areas
# 4                                          1
# 5         Residential, Rural and other Areas
# 6         Residential, Rural and other Areas
# 7                                          1
# 8         Residential, Rural and other Areas
# 9                                          1
# 10        Residential, Rural and other Areas
# 11        Residential, Rural and other Areas
# 12                                         1
# 13        Residential, Rural and other Areas
# 14        Residential, Rural and other Areas
# 15        Residential, Rural and other Areas
# 16                                         1
# 17        Residential, Rural and other Areas
# 18                                         1
# 19        Residential, Rural and other Areas
# 20        Residential, Rural and other Areas
# ...

# %%
from sklearn.preprocessing import LabelEncoder 
labelencoder=LabelEncoder()

# %%
df['state']=labelencoder.fit_transform(df['state'])

# %%
df.head()
# Out:
#         sampling_date  state   location                                type  \
# 0  February - M021990      0  Hyderabad  Residential, Rural and other Areas
# 1  February - M021990      0  Hyderabad                                   1
# 2  February - M021990      0  Hyderabad  Residential, Rural and other Areas
# 3     March - M031990      0  Hyderabad  Residential, Rural and other Areas
# 4     March - M031990      0  Hyderabad                                   1
#
#    so2   no2  rspm  spm  pm2_5        date
# 0  4.8  17.4   NaN  NaN    NaN  1990-02-01
# 1  3.1   7.0   NaN  NaN    NaN  1990-02-01
# 2  6.2  28.5   NaN  NaN    NaN  1990-02-01
# 3  6.3  14.7   NaN  NaN    NaN  1990-03-01
# 4  4.7   7.5   NaN  NaN    NaN  1990-03-01

# %% [markdown]
# # Error Correction

# %%
df.isnull().sum()
# Out:
# sampling_date         0
# state                 0
# location              0
# type               5390
# so2               34643
# no2               16230
# rspm              40219
# spm              237380
# pm2_5            426421
# date                  0
# dtype: int64

# %%
df=df.fillna(df.median())

# %%
df.isnull().sum()
# Out:
# sampling_date       0
# state               0
# location            0
# type             5390
# so2                 0
# no2                 0
# rspm                0
# spm                 0
# pm2_5               0
# date                0
# dtype: int64

# %%
df.describe()
# Out:
#                state            so2            no2           rspm  \
# count  435735.000000  435735.000000  435735.000000  435735.000000
# mean       17.966833      10.604475      25.667759     107.094768
# std         9.471742      10.750998      18.169590      71.541582
# min         0.000000       0.000000       0.000000       0.000000
# 25%        12.000000       5.000000      14.000000      59.000000
# 50%        18.000000       8.000000      22.000000      90.000000
# 75%        26.000000      13.000000      32.000000     135.000000
# max        33.000000     909.000000     876.000000    6307.033333
#
#                  spm          pm2_5
# count  435735.000000  435735.000000
# mean      202.378893      32.187921
# std       103.522497       4.683486
# min         0.000000       3.000000
# 25%       187.000000      32.000000
# 50%       187.000000      32.000000
# 75%       187.000000      32.000000
# max      3380.000000     504.000000

# %% [markdown]
# # data Modeling Building

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn import svm

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
#splitting our dataset
x=df.drop('type',axis=1)

# %%
y=df.type

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
#create a svm classifier
clf=svm.SVC(kernel='linear')

# %%
df['type']
# Out:
# 0         Residential, Rural and other Areas
# 1                                          1
# 2         Residential, Rural and other Areas
# 3         Residential, Rural and other Areas
# 4                                          1
# 5         Residential, Rural and other Areas
# 6         Residential, Rural and other Areas
# 7                                          1
# 8         Residential, Rural and other Areas
# 9                                          1
# 10        Residential, Rural and other Areas
# 11        Residential, Rural and other Areas
# 12                                         1
# 13        Residential, Rural and other Areas
# 14        Residential, Rural and other Areas
# 15        Residential, Rural and other Areas
# 16                                         1
# 17        Residential, Rural and other Areas
# 18                                         1
# 19        Residential, Rural and other Areas
# 20        Residential, Rural and other Areas
# ...

# %%
from sklearn import metrics

# %% [markdown]
# # data integration

# %%
#handling missing values
COLS=['so2','no2','rspm','spm']

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
df[COLS]=imputer.fit_transform(df[COLS])

# %%
df.head()
# Out:
#         sampling_date  state   location                                type  \
# 0  February - M021990      0  Hyderabad  Residential, Rural and other Areas
# 1  February - M021990      0  Hyderabad                                   1
# 2  February - M021990      0  Hyderabad  Residential, Rural and other Areas
# 3     March - M031990      0  Hyderabad  Residential, Rural and other Areas
# 4     March - M031990      0  Hyderabad                                   1
#
#    so2   no2  rspm    spm  pm2_5        date
# 0  4.8  17.4  90.0  187.0   32.0  1990-02-01
# 1  3.1   7.0  90.0  187.0   32.0  1990-02-01
# 2  6.2  28.5  90.0  187.0   32.0  1990-02-01
# 3  6.3  14.7  90.0  187.0   32.0  1990-03-01
# 4  4.7   7.5  90.0  187.0   32.0  1990-03-01
